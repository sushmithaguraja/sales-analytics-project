# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/clean_sales.csv')

# Convert 'Sales' column to numeric, coercing errors to NaN
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# Drop rows where 'Sales' became NaN after conversion (optional, depending on desired handling)
df.dropna(subset=['Sales'], inplace=True)

print(df.columns)
df.groupby('Product Category')['Sales'].sum().plot(kind='bar')
plt.show()
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Order Quantity', 'Sales',
#        'Discount', 'Ship Mode', 'Profit', 'Unit Price', 'Shipping Cost',
#        'Customer Name', 'Province', 'Region', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Name',
#        'Product Container', 'Ship Date', 'Year', 'Month'],
#       dtype='object')
